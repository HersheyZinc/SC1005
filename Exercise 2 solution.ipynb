# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")
df = df.select_dtypes(include='int64')
df = df.drop(['Id','YearBuilt','YrSold','MSSubClass','OverallQual','OverallCond'], axis=1)
df
# Out:
#       LotArea  YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0        8450          2003         706           0        150          856
# 1        9600          1976         978           0        284         1262
# 2       11250          2002         486           0        434          920
# 3        9550          1970         216           0        540          756
# 4       14260          2000         655           0        490         1145
# ...       ...           ...         ...         ...        ...          ...
# 1455     7917          2000           0           0        953          953
# 1456    13175          1988         790         163        589         1542
# 1457     9042          2006         275           0        877         1152
# 1458     9717          1996          49        1029          0         1078
# 1459     9937          1965         830         290        136         1256
#
# ...

# %%
df.describe()
# Out:
#              LotArea  YearRemodAdd   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  \
# count    1460.000000   1460.000000  1460.000000  1460.000000  1460.000000
# mean    10516.828082   1984.865753   443.639726    46.549315   567.240411
# std      9981.264932     20.645407   456.098091   161.319273   441.866955
# min      1300.000000   1950.000000     0.000000     0.000000     0.000000
# 25%      7553.500000   1967.000000     0.000000     0.000000   223.000000
# 50%      9478.500000   1994.000000   383.500000     0.000000   477.500000
# 75%     11601.500000   2004.000000   712.250000     0.000000   808.000000
# max    215245.000000   2010.000000  5644.000000  1474.000000  2336.000000
#
#        TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF    GrLivArea  ...  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1460.000000  ...
# mean   1057.429452  1162.626712   346.992466      5.844521  1515.463699  ...
# ...

# %%
sb.set(style="darkgrid", color_codes=True)

# %%
sales = df['SalePrice']
f, axes = plt.subplots(1, 1, figsize=(24,4))
sb.boxplot(data=sales, orient='h')


sb.displot(sales, aspect=5)


f, axes = plt.subplots(1, 1, figsize=(24,4))
sb.kdeplot(sales)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
lotarea = df['LotArea']
f, axes = plt.subplots(1, 1, figsize=(24,4))
sb.boxplot(data=lotarea, orient='h')


sb.displot(lotarea, aspect=4)


f, axes = plt.subplots(1, 1, figsize=(24,4))
sb.kdeplot(lotarea)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='Density'>

# %%
sb.jointplot(x=lotarea, y=sales, color='green')
